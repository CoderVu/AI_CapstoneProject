# %%
import cv2
import pickle
import numpy as np
import os
import requests
import tensorflow as tf
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
from tensorflow.keras.applications.efficientnet import EfficientNetB3, preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from numpy.linalg import norm

# %%
# Load EfficientNetB3 và hàm trích xuất đặc trưng
def load_model():
    """Tải mô hình EfficientNetB3"""
    base_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
    base_model.trainable = False
    model = tf.keras.Sequential([
        base_model,
        GlobalMaxPooling2D()
    ])
    return model

def extract_features(img_path, model):
    """Trích xuất đặc trưng ảnh từ EfficientNetB3"""
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    expanded_img_array = np.expand_dims(img_array, axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)

    result = model.predict(preprocessed_img).flatten()
    normalized_result = result / norm(result)  # Chuẩn hóa L2
    return normalized_result
# Hàm tạo ảnh mới bằng Data Augmentation
def augment_image(img_path):
    """Tạo ảnh mới bằng Data Augmentation"""
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        brightness_range=[0.8, 1.2]
    )

    aug_iter = datagen.flow(img_array, batch_size=1)
    aug_img = next(aug_iter)[0].astype(np.uint8)
    return aug_img
# Hàm tạo ảnh mới bằng Data Augmentation
def augment_image(img_path):
    """Tạo ảnh mới bằng Data Augmentation"""
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        brightness_range=[0.8, 1.2]
    )

    aug_iter = datagen.flow(img_array, batch_size=1)
    aug_img = next(aug_iter)[0].astype(np.uint8)
    return aug_img
def save_data(features_dict):
    """Lưu embeddings và filenames"""
    filenames = np.array(list(features_dict.keys()))
    feature_list = np.array(list(features_dict.values()))

    if len(feature_list) > 5:
        n_components = min(512, len(feature_list))
        pca = PCA(n_components=n_components)
        reduced_features = pca.fit_transform(feature_list)
        pickle.dump(pca, open("pca.pkl", "wb"))
        print(f"✅ Áp dụng PCA với {n_components} thành phần!")

    pickle.dump(features_dict, open("features.pkl", "wb"))
    pickle.dump(filenames, open("filenames.pkl", "wb"))

    # Tạo mô hình Nearest Neighbors
    nn_model = NearestNeighbors(n_neighbors=4, metric="cosine")
    nn_model.fit(feature_list)
    pickle.dump(nn_model, open("nn_model.pkl", "wb"))

    print("✅ Đã lưu embeddings & NearestNeighbors model thành công!")
def save_data(features_dict):
    """Lưu embeddings và filenames"""
    filenames = np.array(list(features_dict.keys()))
    feature_list = np.array(list(features_dict.values()))
    
    save_dir = "net3"
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Giảm chiều với PCA nếu có đủ dữ liệu
    if len(feature_list) > 5:
        n_components = min(512, len(feature_list))  # Không vượt quá số lượng ảnh
        pca = PCA(n_components=n_components)
        feature_list = pca.fit_transform(feature_list)
        pickle.dump(pca, open(os.path.join(save_dir, "pca.pkl"), "wb"))
        print(f"✅ Áp dụng PCA với {n_components} thành phần!")

    pickle.dump(features_dict, open(os.path.join(save_dir, "features.pkl"), "wb"))
    pickle.dump(filenames, open(os.path.join(save_dir, "filenames.pkl"), "wb"))

    # Tạo mô hình Nearest Neighbors
    nn_model = NearestNeighbors(n_neighbors=4, metric="cosine")
    nn_model.fit(feature_list)
    pickle.dump(nn_model, open(os.path.join(save_dir, "nn_model.pkl"), "wb"))

    print("✅ Đã lưu embeddings & NearestNeighbors model thành công!")

# Hàm tải dữ liệu từ API và trích xuất đặc trưng
def get_image_data(api_url, model):
    """Lấy danh sách ảnh từ API và trích xuất đặc trưng"""
    response = requests.get(api_url)
    data = response.json()

    if response.status_code == 200 and "data" in data:
        images = data["data"]
    else:
        print("❌ Không thể lấy danh sách ảnh từ API!")
        return None

    # Tạo thư mục lưu ảnh nếu chưa tồn tại
    if not os.path.exists("temp"):
        os.makedirs("temp")
    if not os.path.exists("temp/augmented"):
        os.makedirs("temp/augmented")
    if not os.path.exists("temp/original"):
        os.makedirs("temp/original")
    

    features_dict = {}

    for img_info in images:
        img_url = img_info["path"]
        filename = os.path.basename(img_url)

        try:
            # Tải ảnh từ URL
            img_response = requests.get(img_url, stream=True)
            if img_response.status_code == 200:
                img_path = f"temp/original/{filename}"
                with open(img_path, "wb") as f:
                    f.write(img_response.content)

                # Trích xuất đặc trưng từ ảnh gốc
                features = extract_features(img_path, model)
                features_dict[filename] = features

                # Tạo ảnh augmentation và lưu vào thư mục "temp/augmented"
                aug_img = augment_image(img_path)
                aug_img_path = f"temp/augmented/{filename}"
                cv2.imwrite(aug_img_path, cv2.cvtColor(aug_img, cv2.COLOR_RGB2BGR))

                # Trích xuất đặc trưng từ ảnh augmentation
                aug_features = extract_features(aug_img_path, model)
                features_dict[f"{filename}"] = aug_features

            else:
                print(f"⚠️ Không thể đọc ảnh từ {img_url}")

        except Exception as e:
            print(f"❌ Lỗi khi xử lý ảnh {img_url}: {e}")

    return features_dict
# Chạy toàn bộ quy trình
API_URL = "http://localhost:8080/api/v1/public/images"  # Thay bằng URL API của bạn
model = load_model()
features_dict = get_image_data(API_URL, model)
if features_dict:
    save_data(features_dict)

# %%
import cv2
import pickle
import numpy as np
import os
import requests
import tensorflow as tf
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
from tensorflow.keras.applications.efficientnet import EfficientNetB3, preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from numpy.linalg import norm

def load_model():
    """Tải mô hình EfficientNetB3"""
    base_model = EfficientNetB3(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
    base_model.trainable = False
    model = tf.keras.Sequential([
        base_model,
        GlobalMaxPooling2D()
    ])
    return model

def extract_features(img_path, model):
    """Trích xuất đặc trưng ảnh từ EfficientNetB3"""
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    expanded_img_array = np.expand_dims(img_array, axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)

    result = model.predict(preprocessed_img).flatten()
    normalized_result = result / norm(result)  # Chuẩn hóa L2
    return normalized_result
# Hàm tạo ảnh mới bằng Data Augmentation
def augment_image(img_path):
    """Tạo ảnh mới bằng Data Augmentation"""
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        brightness_range=[0.8, 1.2]
    )

    aug_iter = datagen.flow(img_array, batch_size=1)
    aug_img = next(aug_iter)[0].astype(np.uint8)
    return aug_img
# Hàm tạo ảnh mới bằng Data Augmentation
def augment_image(img_path):
    """Tạo ảnh mới bằng Data Augmentation"""
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        brightness_range=[0.8, 1.2]
    )

    aug_iter = datagen.flow(img_array, batch_size=1)
    aug_img = next(aug_iter)[0].astype(np.uint8)
    return aug_img

def send_vector_features(image_id, vector_features, api_url):
    """Gửi vector features lên server"""
    endpoint = f"{api_url}/image/add/vector_feature"
    # Convert numpy array to comma-separated string
    vector_features_str = ','.join(map(str, vector_features.tolist()))
    payload = {
        "id": image_id,
        "vectorFeatures": vector_features_str  # Send as string instead of list
    }
    try:
        response = requests.post(endpoint, json=payload)
        if response.status_code == 200:
            print(f"✅ Đã lưu vector features cho ảnh {image_id}")
            return True
        else:
            print(f"❌ Lỗi khi lưu vector features cho ảnh {image_id}: {response.text}")
            return False
    except Exception as e:
        print(f"❌ Lỗi khi gửi request: {e}")
        return False

def save_data(features_dict):
    """Lưu embeddings và filenames"""
    filenames = np.array(list(features_dict.keys()))
    feature_list = np.array(list(features_dict.values()))
    
    save_dir = "app/net3"
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Giảm chiều với PCA nếu có đủ dữ liệu
    if len(feature_list) > 5:
        n_components = min(512, len(feature_list))  # Không vượt quá số lượng ảnh
        pca = PCA(n_components=n_components)
        feature_list = pca.fit_transform(feature_list)
        pickle.dump(pca, open(os.path.join(save_dir, "pca.pkl"), "wb"))
        print(f"✅ Áp dụng PCA với {n_components} thành phần!")

    pickle.dump(features_dict, open(os.path.join(save_dir, "features.pkl"), "wb"))
    pickle.dump(filenames, open(os.path.join(save_dir, "filenames.pkl"), "wb"))

    # Tạo mô hình Nearest Neighbors
    nn_model = NearestNeighbors(n_neighbors=4, metric="cosine")
    nn_model.fit(feature_list)
    pickle.dump(nn_model, open(os.path.join(save_dir, "nn_model.pkl"), "wb"))

    print("✅ Đã lưu embeddings & NearestNeighbors model thành công!")

def process_images(api_url, process_all=False):
    """Xử lý ảnh và trích xuất đặc trưng
    
    Args:
        api_url: Base URL của API (ví dụ: http://localhost:8080/api/v1/public)
        process_all: Nếu True, xử lý tất cả ảnh. Nếu False, chỉ xử lý ảnh chưa có vector features
    """
    # Lấy danh sách ảnh từ API
    response = requests.get(f"{api_url}/images")
    data = response.json()

    if response.status_code != 200 or "data" not in data:
        print("❌ Không thể lấy danh sách ảnh từ API!")
        return None

    images = data["data"]
    total_images = len(images)
    print(f"\n📊 Thống kê ảnh:")
    print(f"   - Tổng số ảnh trong hệ thống: {total_images}")
    
    # Đếm số ảnh đã có vector features (không tính null hoặc empty string)
    images_with_features = sum(1 for img in images if img.get("vectorFeatures") and img.get("vectorFeatures").strip())
    print(f"   - Số ảnh đã có vector features hợp lệ: {images_with_features}")
    print(f"   - Số ảnh cần trích xuất đặc trưng: {total_images - images_with_features if not process_all else total_images}")
    
    # Tạo thư mục data_extract_feature nếu chưa tồn tại
    base_dir = "data_extract_feature"
    original_dir = os.path.join(base_dir, "original")
    augmented_dir = os.path.join(base_dir, "augmented")
    
    for dir_name in [base_dir, original_dir, augmented_dir]:
        if not os.path.exists(dir_name):
            os.makedirs(dir_name)
            print(f"✅ Đã tạo thư mục {dir_name}")

    features_dict = {}
    processed_count = 0
    failed_count = 0
    model = load_model()
    print("\n🔄 Bắt đầu xử lý ảnh...")

    for idx, img_info in enumerate(images, 1):
        # Bỏ qua ảnh đã có vector features hợp lệ nếu không xử lý tất cả
        if not process_all and img_info.get("vectorFeatures") and img_info.get("vectorFeatures").strip():
            continue

        img_url = img_info["path"]
        image_id = img_info["id"]
        filename = os.path.basename(img_url)
        print(f"\n📝 Đang xử lý ảnh {idx}/{total_images}: {filename}")

        try:
            # Tải ảnh từ URL
            img_response = requests.get(img_url, stream=True)
            if img_response.status_code == 200:
                # Lưu ảnh gốc vào thư mục original
                img_path = os.path.join(original_dir, filename)
                with open(img_path, "wb") as f:
                    f.write(img_response.content)
                print(f"   ✅ Đã lưu ảnh gốc: {filename}")

                # Trích xuất đặc trưng từ ảnh gốc
                features = extract_features(img_path, model)
                print(f"   ✅ Đã trích xuất đặc trưng ({len(features)} chiều)")
                
                # Gửi vector features lên server
                if send_vector_features(image_id, features, api_url):
                    features_dict[filename] = features
                    processed_count += 1
                    print(f"   ✅ Đã lưu vector features lên database")

                # Tạo ảnh augmentation và lưu vào thư mục augmented
                aug_img = augment_image(img_path)
                aug_img_path = os.path.join(augmented_dir, filename)
                cv2.imwrite(aug_img_path, cv2.cvtColor(aug_img, cv2.COLOR_RGB2BGR))
                print(f"   ✅ Đã tạo và lưu ảnh augmentation")

                # Trích xuất đặc trưng từ ảnh augmentation
                aug_features = extract_features(aug_img_path, model)
                features_dict[f"aug_{filename}"] = aug_features
                print(f"   ✅ Đã trích xuất đặc trưng từ ảnh augmentation")

            else:
                print(f"   ⚠️ Không thể đọc ảnh từ {img_url}")
                failed_count += 1

        except Exception as e:
            print(f"   ❌ Lỗi khi xử lý ảnh {img_url}: {e}")
            failed_count += 1

    print(f"\n📊 Kết quả xử lý:")
    print(f"   - Tổng số ảnh đã xử lý thành công: {processed_count}")
    print(f"   - Số ảnh xử lý thất bại: {failed_count}")
    print(f"   - Tổng số vector features đã lưu (bao gồm cả augmentation): {len(features_dict)}")
    
    if features_dict:
        save_data(features_dict)
        print(f"   - Đã lưu tất cả features vào thư mục app/net3/")
    
    return features_dict

if __name__ == "__main__":
    API_URL = "http://localhost:8080/api/v1/public"  # Base URL của API
    # Chỉ xử lý ảnh chưa có vector features
    process_images(API_URL, process_all=True)
# Out:
# 📊 Thống kê ảnh:
#    - Tổng số ảnh trong hệ thống: 50
#    - Số ảnh đã có vector features hợp lệ: 50
#    - Số ảnh cần trích xuất đặc trưng: 50
#
# 🔄 Bắt đầu xử lý ảnh...
#
# 📝 Đang xử lý ảnh 1/50: 60b58d41-d6fb-4aa1-8a14-09694fec55a2-ao-so-mi_3.jpg
#    ✅ Đã lưu ảnh gốc: 60b58d41-d6fb-4aa1-8a14-09694fec55a2-ao-so-mi_3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 01f668f8-ea2b-430e-ab96-92cfa65dc4cc
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 2/50: 33713f51-c95f-42f5-ae92-75cfa931e2fb-ao.webp
#    ✅ Đã lưu ảnh gốc: 33713f51-c95f-42f5-ae92-75cfa931e2fb-ao.webp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 064efbdf-3c97-443b-96c4-30e740e6fe43
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 3/50: 79d6ca90-87ae-4991-9004-7905e7a68578-ao-so-mi_33.jpg
#    ✅ Đã lưu ảnh gốc: 79d6ca90-87ae-4991-9004-7905e7a68578-ao-so-mi_33.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 0a8e12fe-b4da-4833-bff1-ab448cbb59dd
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 4/50: 79ecfdda-29fa-4aaa-9023-0a82dd5cc9b9-quan_short_3.jpg
#    ✅ Đã lưu ảnh gốc: 79ecfdda-29fa-4aaa-9023-0a82dd5cc9b9-quan_short_3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 0f0315c6-e474-45d3-922c-710a210cc1a1
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 5/50: 0486dd75-a08b-4f1a-a5da-ba6a0daaf5cb-ao-khoac_29.jpg
#    ✅ Đã lưu ảnh gốc: 0486dd75-a08b-4f1a-a5da-ba6a0daaf5cb-ao-khoac_29.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 182da69d-ee68-4b29-b4bb-da923e2078e1
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 6/50: 69304cea-bd99-4f87-aea0-a54793b13f0c-ao-khoac_35.jpg
#    ✅ Đã lưu ảnh gốc: 69304cea-bd99-4f87-aea0-a54793b13f0c-ao-khoac_35.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 253aca91-43b9-4950-83ea-a71e1256e784
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 7/50: c0625ab8-64b5-436b-b448-d5e9d9c881f0-quan_14.jpg
#    ✅ Đã lưu ảnh gốc: c0625ab8-64b5-436b-b448-d5e9d9c881f0-quan_14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 25e4d047-5343-4cfb-87c9-5773cadc3d50
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 8/50: 94ba3bc7-4216-487b-8c59-53b1c9b4d4ab-img_2370.webp
#    ✅ Đã lưu ảnh gốc: 94ba3bc7-4216-487b-8c59-53b1c9b4d4ab-img_2370.webp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 30e0c866-b1e9-4a93-94de-540fdae09a2e
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 9/50: 15b3e7e4-dd66-4948-a397-4cea8fa46226-quan_15.jpg
#    ✅ Đã lưu ảnh gốc: 15b3e7e4-dd66-4948-a397-4cea8fa46226-quan_15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 30fcf5bf-878c-4d76-8b9d-657bb343d07a
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 10/50: e3d516ee-9e3e-42a2-b6fb-6369a62441cd-25524914_58696644_2048.webp
#    ✅ Đã lưu ảnh gốc: e3d516ee-9e3e-42a2-b6fb-6369a62441cd-25524914_58696644_2048.webp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 313b2a8b-6392-496e-9746-c5ebb69a67c6
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 11/50: 4e8d6c89-64a1-42d8-b405-06b6a9356e56-ao-so-mi_27.jpg
#    ✅ Đã lưu ảnh gốc: 4e8d6c89-64a1-42d8-b405-06b6a9356e56-ao-so-mi_27.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 33998c0e-d9f3-41d4-be9b-0bd3575d92c9
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 12/50: e1c365a4-646f-42fc-bf4c-326f7752b7dc-ao-so-mi_39.jpg
#    ✅ Đã lưu ảnh gốc: e1c365a4-646f-42fc-bf4c-326f7752b7dc-ao-so-mi_39.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 364277d8-4215-4672-9a0d-43bcc0823483
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 13/50: 7c3fc61f-0c1a-4754-afc4-a355d16214e4-quan_short_1.jpg
#    ✅ Đã lưu ảnh gốc: 7c3fc61f-0c1a-4754-afc4-a355d16214e4-quan_short_1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 41143093-3332-4a26-9a7c-374f9b512ded
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 14/50: f6e556e3-a0b3-4c70-9a8e-e9f947727d41-ao-so-mi_7.jpg
#    ✅ Đã lưu ảnh gốc: f6e556e3-a0b3-4c70-9a8e-e9f947727d41-ao-so-mi_7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 4265e507-60dc-4a4c-97c0-2be316c21cc8
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 15/50: 190a1c75-84ac-4292-9731-d989757baf38-quan_short_4.jpg
#    ✅ Đã lưu ảnh gốc: 190a1c75-84ac-4292-9731-d989757baf38-quan_short_4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 43528312-2999-46c3-9125-6fa23f0201c0
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 16/50: 96d8f26c-92de-4428-8649-b62e47e5a267-ao-so-mi_17.jpg
#    ✅ Đã lưu ảnh gốc: 96d8f26c-92de-4428-8649-b62e47e5a267-ao-so-mi_17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 4ebfd1ad-931e-48a9-9cfa-1de4eb35de6a
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 17/50: 766571b3-dacf-42dc-b36f-38c5d04cb715-ao-so-mi_29.jpg
#    ✅ Đã lưu ảnh gốc: 766571b3-dacf-42dc-b36f-38c5d04cb715-ao-so-mi_29.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 50212627-5418-43fe-813a-7bd7762a101c
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 18/50: be1e27c0-a050-4144-bf97-3b67145ac6a0-quan_10.jpg
#    ✅ Đã lưu ảnh gốc: be1e27c0-a050-4144-bf97-3b67145ac6a0-quan_10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 5441764e-5b85-4c7a-b9b3-1f063fba20ca
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 19/50: 79ac7b38-34b2-4ad3-8c07-881d1433c3f7-ao-khoac_20.jpg
#    ✅ Đã lưu ảnh gốc: 79ac7b38-34b2-4ad3-8c07-881d1433c3f7-ao-khoac_20.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 54a59821-f967-42e2-ae51-4ea4a0f5870e
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 20/50: 4ae87ef5-2b1d-41c1-b930-5a36df7297e5-quan_111.jpg
#    ✅ Đã lưu ảnh gốc: 4ae87ef5-2b1d-41c1-b930-5a36df7297e5-quan_111.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 59cd9b65-661e-48b9-af05-a005a3d993b8
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 21/50: d1a89f7d-b2d4-41b6-b46e-6c7a5df995bf-quan_14.jpg
#    ✅ Đã lưu ảnh gốc: d1a89f7d-b2d4-41b6-b46e-6c7a5df995bf-quan_14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 5e834c40-505b-4e4f-9fb4-b0f5e6e11309
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 22/50: 1d954490-5438-48bb-9d30-89c030f51ff9-25524914_58696661_2048.webp
#    ✅ Đã lưu ảnh gốc: 1d954490-5438-48bb-9d30-89c030f51ff9-25524914_58696661_2048.webp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 5eb0def0-7f31-419b-9388-6c501f6c6326
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 23/50: efea7401-1504-4edc-af96-44b738bf844d-img_2352.webp
#    ✅ Đã lưu ảnh gốc: efea7401-1504-4edc-af96-44b738bf844d-img_2352.webp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 638d526d-124f-4781-84d2-b08e0af5b42c
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 24/50: 2058dd31-1ec5-4dc8-ac6f-a1710264e367-img_2358.webp
#    ✅ Đã lưu ảnh gốc: 2058dd31-1ec5-4dc8-ac6f-a1710264e367-img_2358.webp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 66e46287-e94b-48b4-9168-3ba9986e2a7c
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 25/50: 89c043b3-3b41-4a72-b0c5-1a8559da67ee-quan_185.jpg
#    ✅ Đã lưu ảnh gốc: 89c043b3-3b41-4a72-b0c5-1a8559da67ee-quan_185.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 6c73ce9a-cd32-4361-bc21-5ab55f440581
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 26/50: a2f54465-7dc5-4179-be20-87bb14b94361-ao-so-mi_31.jpg
#    ✅ Đã lưu ảnh gốc: a2f54465-7dc5-4179-be20-87bb14b94361-ao-so-mi_31.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 72b93a72-b0a0-481c-a632-c950d43da575
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 27/50: a1ff8fcb-2355-4f87-b1c5-21e5b5876179-ao-khoac_37.jpg
#    ✅ Đã lưu ảnh gốc: a1ff8fcb-2355-4f87-b1c5-21e5b5876179-ao-khoac_37.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 766e58cd-6d76-4bb2-b66c-4055345e0459
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 28/50: df070d78-f3dc-4803-b457-37c0df468548-ao-khoac_22.jpg
#    ✅ Đã lưu ảnh gốc: df070d78-f3dc-4803-b457-37c0df468548-ao-khoac_22.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 7e310cfd-933b-49da-8261-cee5d32e7ff5
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 29/50: e353ca21-e874-406a-b82a-fc333aa07643-quan_1.jpg
#    ✅ Đã lưu ảnh gốc: e353ca21-e874-406a-b82a-fc333aa07643-quan_1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 7ec747b9-bed6-43db-a01a-f60d82dae2b5
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 30/50: b562cfb7-899b-4f21-acb3-46ed9cfbf602-quan_143.jpg
#    ✅ Đã lưu ảnh gốc: b562cfb7-899b-4f21-acb3-46ed9cfbf602-quan_143.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 8aa168fd-4a8c-4424-8e79-9a4c0e21ad06
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 31/50: f07d1008-0924-4108-9c61-7f0421d99328-quan_187.jpg
#    ✅ Đã lưu ảnh gốc: f07d1008-0924-4108-9c61-7f0421d99328-quan_187.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh 8d756a01-1adf-46d3-86f5-d6d8409757fc
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 32/50: acf742a2-c950-42d4-b2a6-3000d56e425b-ao-khoac_37.jpg
#    ✅ Đã lưu ảnh gốc: acf742a2-c950-42d4-b2a6-3000d56e425b-ao-khoac_37.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh a1a03f4a-8186-4f29-9bb9-13f553b599a4
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 33/50: 4bef4a45-0d96-40d4-aa54-c5bb037d039d-quan_111.jpg
#    ✅ Đã lưu ảnh gốc: 4bef4a45-0d96-40d4-aa54-c5bb037d039d-quan_111.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh a2ff42a7-7fb4-4722-8481-5db51ee5f465
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 34/50: fcdc3973-18f3-4bde-89d8-bd9ea2e9c4c8-quan_1.jpg
#    ✅ Đã lưu ảnh gốc: fcdc3973-18f3-4bde-89d8-bd9ea2e9c4c8-quan_1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh a4ac1dd2-e496-4822-af5b-134d5ce93f20
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 35/50: 610d765d-89fe-4cda-81ce-583af7f23988-quan_short_2.jpg
#    ✅ Đã lưu ảnh gốc: 610d765d-89fe-4cda-81ce-583af7f23988-quan_short_2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh be108c6e-e07c-443c-b868-e5047de580a3
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 36/50: 02b2ae4e-7096-4f88-8ce9-a42776beae02-quan_141.jpg
#    ✅ Đã lưu ảnh gốc: 02b2ae4e-7096-4f88-8ce9-a42776beae02-quan_141.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh c55761e7-4bb1-4ca3-9fda-8358fc77d8e4
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 37/50: 1025167b-f326-4f0c-b88b-f02d385d1000-ao-so-mi_5.jpg
#    ✅ Đã lưu ảnh gốc: 1025167b-f326-4f0c-b88b-f02d385d1000-ao-so-mi_5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh c74112f2-9302-42ee-925f-abc48ad8d863
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 38/50: 9c96e677-7240-40ae-8de8-7f083d45b1f4-quan_186.jpg
#    ✅ Đã lưu ảnh gốc: 9c96e677-7240-40ae-8de8-7f083d45b1f4-quan_186.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh c877c287-aa38-46bc-af3f-bfee80171ce3
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 39/50: d180dc03-eea6-4749-b9d3-87db772d3173-ao-khoac_16.jpg
#    ✅ Đã lưu ảnh gốc: d180dc03-eea6-4749-b9d3-87db772d3173-ao-khoac_16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh ca64a1df-1202-4aad-94da-8c6d295aec36
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 40/50: 770f342a-e6b7-49c9-968a-16efdcc48b77-25524914_58696676_2048.webp
#    ✅ Đã lưu ảnh gốc: 770f342a-e6b7-49c9-968a-16efdcc48b77-25524914_58696676_2048.webp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh cc68af68-e44b-4a6f-b935-d33164731574
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 41/50: abfb498a-7e42-4352-88a4-fe812a6feb91-quan_short_3.jpg
#    ✅ Đã lưu ảnh gốc: abfb498a-7e42-4352-88a4-fe812a6feb91-quan_short_3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh d071cde1-abe5-4108-8a49-bcfd3886ee80
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 42/50: 5eeb33c3-7284-4fc6-8e5c-636d67aece4b-quan_6.jpg
#    ✅ Đã lưu ảnh gốc: 5eeb33c3-7284-4fc6-8e5c-636d67aece4b-quan_6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh d67614f0-9519-4547-b510-70c05c37bbd1
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 43/50: 8e28faed-c539-46ef-a649-d554599d2de2-ao-khoac_15.jpg
#    ✅ Đã lưu ảnh gốc: 8e28faed-c539-46ef-a649-d554599d2de2-ao-khoac_15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh d6da3991-4e26-4d3b-bd81-e603bcbc88e4
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 44/50: 3b0e257f-3aaf-4ace-8449-53c69759bbc2-quan_139.jpg
#    ✅ Đã lưu ảnh gốc: 3b0e257f-3aaf-4ace-8449-53c69759bbc2-quan_139.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh db394209-a271-4f69-bb25-056bb15bec52
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 45/50: c0900d81-ee99-437b-b882-5aaa61e67a0b-ao-so-mi_39.jpg
#    ✅ Đã lưu ảnh gốc: c0900d81-ee99-437b-b882-5aaa61e67a0b-ao-so-mi_39.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh deb852b9-be3f-4207-bc78-b8630172e872
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 46/50: 7a36e94a-4aa7-4924-a4a2-7e7eff8ce3f1-ao-so-mi_23.jpg
#    ✅ Đã lưu ảnh gốc: 7a36e94a-4aa7-4924-a4a2-7e7eff8ce3f1-ao-so-mi_23.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh e351f3c4-c395-49d4-bb25-31e6358122e7
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 47/50: fc7f4f94-411b-4142-ab18-7c448646c9bf-ao-khoac_31.jpg
#    ✅ Đã lưu ảnh gốc: fc7f4f94-411b-4142-ab18-7c448646c9bf-ao-khoac_31.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh e514d8ea-4a8a-47c9-adff-d56043930c97
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 48/50: 8edf882b-a9f3-42ec-9180-94945a081986-ao-khoac_21.jpg
#    ✅ Đã lưu ảnh gốc: 8edf882b-a9f3-42ec-9180-94945a081986-ao-khoac_21.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh fa6efbb6-c855-4f18-bfb3-060ed9b0b514
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 49/50: aac22679-3054-4bf8-b9d5-926989b9ea8f-ao-so-mi_34.jpg
#    ✅ Đã lưu ảnh gốc: aac22679-3054-4bf8-b9d5-926989b9ea8f-ao-so-mi_34.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh fa9d15f0-f7f6-4aaf-b465-654406361255
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📝 Đang xử lý ảnh 50/50: 32284cf4-41c1-4deb-bd07-8f6a5206d0ce-ao-khoac_19.jpg
#    ✅ Đã lưu ảnh gốc: 32284cf4-41c1-4deb-bd07-8f6a5206d0ce-ao-khoac_19.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
#    ✅ Đã trích xuất đặc trưng (1536 chiều)
# ✅ Đã lưu vector features cho ảnh fb0b8b5e-047a-4322-ac4b-df8eb2fa0293
#    ✅ Đã lưu vector features lên database
#    ✅ Đã tạo và lưu ảnh augmentation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#    ✅ Đã trích xuất đặc trưng từ ảnh augmentation
#
# 📊 Kết quả xử lý:
#    - Tổng số ảnh đã xử lý thành công: 50
#    - Số ảnh xử lý thất bại: 0
#    - Tổng số vector features đã lưu (bao gồm cả augmentation): 100
# ✅ Áp dụng PCA với 100 thành phần!
# ✅ Đã lưu embeddings & NearestNeighbors model thành công!
#    - Đã lưu tất cả features vào thư mục app/net3/
